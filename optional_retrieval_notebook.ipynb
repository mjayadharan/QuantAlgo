# %%
import requests
import pandas as pd

# %%
api_key = "7OVPSPQGG82Z6EJZ"



# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=HISTORICAL_OPTIONS&symbol=IBM&apikey={}'.format(api_key)
r = requests.get(url)
data = r.json()


data
# Out:
# {'endpoint': 'Historical Options',
#  'message': 'success',
#  'data': [{'contractID': 'IBM240823C00095000',
#    'symbol': 'IBM',
#    'expiration': '2024-08-23',
#    'strike': '95.00',
#    'type': 'call',
#    'last': '0.00',
#    'mark': '99.78',
#    'bid': '98.00',
#    'bid_size': '35',
#    'ask': '101.55',
#    'ask_size': '35',
#    'volume': '0',
#    'open_interest': '0',
#    'date': '2024-08-19',
#    'implied_volatility': '1.64399',
#    'delta': '1.00000',
#    'gamma': '0.00000',
#    'theta': '-0.05061',
#    'vega': '0.00000',
#    'rho': '0.01040'},
#   {'contractID': 'IBM240823P00095000',
#    'symbol': 'IBM',
#    'expiration': '2024-08-23',
#    'strike': '95.00',
#    'type': 'put',
#    'last': '0.00',
#    'mark': '0.01',
#    'bid': '0.00',
#    'bid_size': '0',
#    'ask': '0.01',
#    'ask_size': '500',
#    'volume': '0',
#    'open_interest': '0',
#    'date': '2024-08-19',
#    'implied_volatility': '2.24630',
#    'delta': '-0.00076',
# ...

# %%
pd.DataFrame(data['data'])
# Out:
#               contractID symbol  expiration  strike  type  last   mark    bid  \
# 0     IBM240823C00095000    IBM  2024-08-23   95.00  call  0.00  99.78  98.00
# 1     IBM240823P00095000    IBM  2024-08-23   95.00   put  0.00   0.01   0.00
# 2     IBM240823C00100000    IBM  2024-08-23  100.00  call  0.00  94.62  92.70
# 3     IBM240823P00100000    IBM  2024-08-23  100.00   put  0.00   0.01   0.00
# 4     IBM240823C00105000    IBM  2024-08-23  105.00  call  0.00  89.75  88.00
# ...                  ...    ...         ...     ...   ...   ...    ...    ...
# 1009  IBM260116P00270000    IBM  2026-01-16  270.00   put  0.00  74.95  73.00
# 1010  IBM260116C00280000    IBM  2026-01-16  280.00  call  2.50   2.15   1.80
# 1011  IBM260116P00280000    IBM  2026-01-16  280.00   put  0.00  84.95  83.00
# 1012  IBM260116C00290000    IBM  2026-01-16  290.00  call  2.00   1.97   1.15
# 1013  IBM260116P00290000    IBM  2026-01-16  290.00   put  0.00  94.95  93.00
#
# ...

# %%
pd.DataFrame(data)
# Out:
#                 endpoint  message  \
# 0     Historical Options  success
# 1     Historical Options  success
# 2     Historical Options  success
# 3     Historical Options  success
# 4     Historical Options  success
# ...                  ...      ...
# 1009  Historical Options  success
# 1010  Historical Options  success
# 1011  Historical Options  success
# 1012  Historical Options  success
# 1013  Historical Options  success
#
#                                                    data
# 0     {'contractID': 'IBM240823C00095000', 'symbol':...
# 1     {'contractID': 'IBM240823P00095000', 'symbol':...
# 2     {'contractID': 'IBM240823C00100000', 'symbol':...
# 3     {'contractID': 'IBM240823P00100000', 'symbol':...
# 4     {'contractID': 'IBM240823C00105000', 'symbol':...
# ...                                                 ...
# 1009  {'contractID': 'IBM260116P00270000', 'symbol':...
# 1010  {'contractID': 'IBM260116C00280000', 'symbol':...
# ...
